# %%
from pathlib import Path
import geopandas as gpd

# %%
pine_mountain_file = Path("../data") / "SR190.shp"

# %%
map_gdf = gpd.read_file(pine_mountain_file, engine="fiona")

# %%
map_gdf.plot()
# Out:
# <Axes: >

# %%
geojson_file = Path("../data") / "SR190_curves.geojson"
curve_gdf = gpd.read_file(geojson_file, engine="fiona")

# %%
curve_gdf.plot()
# Out:
# <Axes: >

# %%
curve_gdf
# Out:
#    c_segid  c_sectid  c_id  c_type  c_radius  c_devangle  c_length  \
# 0    SR190         0     0  simple    1067.5        27.4     509.5
# 1    SR190         1     1  simple     898.2        39.3     615.5
# 2    SR190         2     2  simple    2146.8        26.0     975.3
# 3    SR190         3     3  simple     659.3        40.4     462.1
# 4    SR190         4     4  simple     421.6        63.2     462.0
# 5    SR190         5     5  simple     455.7        69.8     554.8
# 6    SR190         6     6  simple    1551.2        35.5     960.3
# 7    SR190         7     7   split    1252.2        32.3     705.4
# 8    SR190         7     8   split    1555.0        23.8     644.6
# 9    SR190         8     9  simple     957.9        42.2     704.9
# 10   SR190         9    10   split     635.1        60.9     675.1
# 11   SR190         9    11   split    1384.9        45.3    1094.2
# 12   SR190        10    12  simple     667.7        47.6     554.1
# ...
